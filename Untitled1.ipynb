# %%
import plotly.graph_objects as go

import networkx as nx

G = nx.random_geometric_graph(200, 0.125)

# %%
nx.complete_graph(5)

# %%
edge_x = []
edge_y = []
for edge in G.edges():
    x0, y0 = G.nodes[edge[0]]['pos']
    x1, y1 = G.nodes[edge[1]]['pos']
    edge_x.append(x0)
    edge_x.append(x1)
    edge_x.append(None)
    edge_y.append(y0)
    edge_y.append(y1)
    edge_y.append(None)

edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='#888'),
    hoverinfo='none',
    mode='lines')

node_x = []
node_y = []
for node in G.nodes():
    x, y = G.nodes[node]['pos']
    node_x.append(x)
    node_y.append(y)

node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers')

# %%
edge_trace
# Out:
# Scatter({
#     'hoverinfo': 'none',
#     'line': {'color': '#888', 'width': 0.5},
#     'mode': 'lines',
#     'x': [0.5940418776731913, 0.6569452114325695, None, ..., 0.9810284340609922,
#           0.9182900300547697, None],
#     'y': [0.7375319690356797, 0.7752848602453951, None, ..., 0.691125026528304,
#           0.7654299381194389, None]
# })

# %%
node_adjacencies = []
node_text = []
for node, adjacencies in enumerate(G.adjacency()):
    node_adjacencies.append(len(adjacencies[1]))
    node_text.append('# of connections: '+str(len(adjacencies[1])))

node_trace.marker.color = node_adjacencies
node_trace.text = node_text

# %%
edge_trace
# Out:
# Scatter({
#     'hoverinfo': 'none',
#     'line': {'color': '#888', 'width': 0.5},
#     'mode': 'lines',
#     'x': [0.5940418776731913, 0.6569452114325695, None, ..., 0.9810284340609922,
#           0.9182900300547697, None],
#     'y': [0.7375319690356797, 0.7752848602453951, None, ..., 0.691125026528304,
#           0.7654299381194389, None]
# })

# %%
fig = go.Figure(data=[edge_trace, node_trace])
fig.show()
